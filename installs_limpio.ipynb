# %%
import pandas as pd
import numpy as np
installs_dtypes = {'application_id': 'category', 'ref_type': 'category', 'device_countrycode': 'category',
                   'device_brand': 'category', 'device_model' : 'category', 'session_user_agent': 'category',
                   'user_agent': 'category', 'kind': 'category', 'device_language': 'category'}
installs = pd.read_csv('installs.csv', dtype = installs_dtypes)

# %%
installs["created"] =  pd.to_datetime(installs["created"], errors = "coerce")

# %%
installs.head()
# Out:
#                    created application_id             ref_type  \
# 0  2019-03-13 01:43:33.445              0  1891515180541284343
# 1  2019-03-13 04:58:35.078              0  1891515180541284343
# 2  2019-03-13 04:20:57.666              0  1891515180541284343
# 3  2019-03-13 04:20:57.698              0  1891515180541284343
# 4  2019-03-10 22:24:56.684              0  1891515180541284343
#
#               ref_hash  click_hash  attributed  implicit   device_countrycode  \
# 0  8464844987297247076         NaN       False     False  6333597102633388268
# 1  3250564871270161533         NaN       False     False  6333597102633388268
# 2  7953318831018100268         NaN       False      True  6333597102633388268
# 3  7953318831018100268         NaN       False     False  6333597102633388268
# 4  8355110941557237501         NaN       False      True  6333597102633388268
#
#              device_brand            device_model  \
# 0   3.083058605577787e+17  4.4452523127597215e+18
# 1   3.083058605577787e+17  4.4452523127597215e+18
# 2  5.1379920467642125e+17   6.026543327929208e+18
# 3  5.1379920467642125e+17   6.026543327929208e+18
# 4   1.083368711068078e+18   7.876611839898798e+18
#
#                   session_user_agent user_agent  \
# 0                                NaN        NaN
# 1                                NaN        NaN
# 2  HasOffers Mobile AppTracking v1.0        NaN
# 3                                NaN        NaN
# 4  HasOffers Mobile AppTracking v1.0        NaN
#
#                              event_uuid  kind wifi trans_id  \
# 0                                   NaN   NaN  NaN      NaN
# 1                                   NaN   NaN  NaN      NaN
# 2  0bfa9b4c-e07a-4522-b32d-138e3165ac98  Open  NaN      NaN
# 3                                   NaN   NaN  NaN      NaN
# 4  8f235a8c-41bf-4399-b33d-c41577c949b0  Open  NaN      NaN
#
#             ip_address         device_language
# 0  5529284367937637301                     NaN
# 1  6098022721363533304                     NaN
# 2  4636407223847323867  3.3013777759776993e+18
# 3  4636407223847323867                     NaN
# 4   685400811232710215  3.3013777759776993e+18

# %%
installs.kind.value_counts()
# Out:
# af_app_opened                 428
# app_open                      212
# EVENT_Homepage                 70
# open                           36
# EVENT_OPEN_APP                 33
# Open                           22
# login_success                  17
# account_summary_first_step     13
# EVENT_LISTINGVIEW_FLIGHT        6
# EVENT_HOMEPAGE                  6
# deeplink                        5
# reattribution                   4
# payment method add              3
# registration                    3
# journey first drop off          2
# af_list_view                    1
# install                         1
# journey drop off                1
# EVENT_PROMO                     1
# journey reserved                1
# Name: kind, dtype: int64

# %%
list(installs.columns)
# Out:
# ['created',
#  'application_id',
#  'ref_type',
#  'ref_hash',
#  'click_hash',
#  'attributed',
#  'implicit',
#  'device_countrycode',
#  'device_brand',
#  'device_model',
#  'session_user_agent',
#  'user_agent',
#  'event_uuid',
#  'kind',
#  'wifi',
#  'trans_id',
#  'ip_address',
#  'device_language']

# %%
installs['attributed'].value_counts()
# Out:
# False    3412
# Name: attributed, dtype: int64

# %%
installs.drop('attributed', axis = 1, inplace = True) #son todas false
installs.drop('click_hash', axis = 1, inplace = True) #son todas NaN

# %%
installs.head(3)
# Out:
#                    created application_id             ref_type  \
# 0  2019-03-13 01:43:33.445              0  1891515180541284343
# 1  2019-03-13 04:58:35.078              0  1891515180541284343
# 2  2019-03-13 04:20:57.666              0  1891515180541284343
#
#               ref_hash  implicit   device_countrycode            device_brand  \
# 0  8464844987297247076     False  6333597102633388268   3.083058605577787e+17
# 1  3250564871270161533     False  6333597102633388268   3.083058605577787e+17
# 2  7953318831018100268      True  6333597102633388268  5.1379920467642125e+17
#
#              device_model                 session_user_agent user_agent  \
# 0  4.4452523127597215e+18                                NaN        NaN
# 1  4.4452523127597215e+18                                NaN        NaN
# 2   6.026543327929208e+18  HasOffers Mobile AppTracking v1.0        NaN
#
#                              event_uuid  kind wifi trans_id  \
# 0                                   NaN   NaN  NaN      NaN
# 1                                   NaN   NaN  NaN      NaN
# 2  0bfa9b4c-e07a-4522-b32d-138e3165ac98  Open  NaN      NaN
#
#             ip_address         device_language
# 0  5529284367937637301                     NaN
# 1  6098022721363533304                     NaN
# 2  4636407223847323867  3.3013777759776993e+18

# %%
installs['trans_id'].value_counts() #????? esta columna podria estar rota
# Out:
# {hash}                                  3
# 22380348598                             1
# 89bda305-bff1-4c22-ae23-1a237eac0002    1
# 44aeb6df-8db4-4b3f-ac67-0a802d479c86    1
# Name: trans_id, dtype: int64
