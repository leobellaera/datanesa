# %%
import pandas as pd
import numpy as np
events_dtypes = {'event_id': 'category', 'ref_type': 'category', 'ref_hash': 'category', 'application_id': 'category',
                   'attributed': 'category', 'device_countrycode': 'category', 'device_os_version': 'category',
                   'device_brand' : 'category', 'device_model' : 'category', 'device_city': 'category', 'session_user_agent': 'category', 'user_agent': 'category', 'carrier': 'category',
                   'kind': 'category', 'device_os' : 'category', 'wifi': 'category', 'connection_type': 'category',
                   'device_language': 'category'}
events = pd.read_csv('events.csv.gzip', dtype = events_dtypes, compression = 'gzip', low_memory=False)

# %%
events["date"] =  pd.to_datetime(events["date"], errors = "coerce")

# %%
events.head()
# Out:
#                       date event_id             ref_type             ref_hash  \
# 0  2019-03-05 00:09:36.966        0  1891515180541284343  2688759737656491380
# 1  2019-03-05 00:09:38.920        1  1891515180541284343  2688759737656491380
# 2  2019-03-05 00:09:26.195        0  1891515180541284343  2688759737656491380
# 3  2019-03-05 00:09:31.107        2  1891515180541284343  2688759737656491380
# 4  2019-03-09 21:00:36.585        3  1891515180541284343  2635154697734164782
#
#   application_id attributed   device_countrycode      device_os_version  \
# 0             38      False  6333597102633388268  5.908703034097298e+17
# 1             38      False  6333597102633388268  5.908703034097298e+17
# 2             38      False  6333597102633388268  5.908703034097298e+17
# 3             38      False  6333597102633388268  5.908703034097298e+17
# 4             38      False  6333597102633388268  7.391843585977942e+18
#
# ...

# %%
events.memory_usage(index=True, deep=False)
# Out:
# Index                       80
# date                  19955384
# event_id               5013870
# ref_type               2494519
# ref_hash              16788964
# application_id         5001238
# attributed             2494439
# device_countrycode     2494431
# device_os_version      2497631
# device_brand           5001086
# device_model           5091758
# device_city            4994982
# session_user_agent     5041486
# trans_id              19955384
# user_agent             5193574
# event_uuid            19955384
# carrier                2497655
# kind                   5013990
# device_os              2494615
# wifi                   2494519
# connection_type        2494447
# ip_address            19955384
# device_language        4995454
# dtype: int64
