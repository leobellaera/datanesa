# %%
import pandas as pd
import numpy as np

# %%
auctions_dtypes = {'auction_type_id': np.float16, 'country': 'category', 'platform': 'category',
                   'ref_type_id': 'category', 'source_id': 'category', 'device_id': 'category'}

auctions = pd.read_csv('auctions.csv', dtype = auctions_dtypes)

auctions.drop('auction_type_id', axis = 1, inplace = True)  #todas Nan

auctions["date"] =  pd.to_datetime(auctions["date"], errors = "coerce")

# %%
clicks_dtypes = {'advertiser': np.int8, 'action_id': np.float16, 'source_id': np.int8, 'country_code': 'category',
                 'latitude': np.float16, 'longitude': np.float16, 'carrier_id': np.float16, 'brand': np.float16,
                 'touchX': np.float16, 'touchY': np.float16, 'ref_hash': 'category'}

clicks = pd.read_csv('clicks.csv', dtype = clicks_dtypes)

clicks.drop('action_id', axis = 1, inplace = True) #todos NaN
clicks.drop('wifi_connection', axis = 1, inplace = True) #todos False

clicks["created"] =  pd.to_datetime(clicks["created"], errors = "coerce") #parseo de fechas

# %%
clicks.head(1)
# Out:
#    advertiser_id  source_id                 created         country_code  \
# 0              2          4 2019-03-06 22:42:12.755  6333597102633388268
#
#    latitude  longitude  carrier_id                         trans_id  \
# 0  1.206055   1.070312         1.0  iGgClCM9exiHF4K31g94XmvHEBSLKIY
#
#        os_minor  agent_device      os_major          specs_brand  brand  \
# 0  6.768137e+18           NaN  3.072849e+18  2733035977666442898    NaN
#
#    timeToClick    touchX    touchY             ref_type             ref_hash
# 0        1.563  0.904785  0.078003  1891515180541284343  1904083516767779093

# %%
auctions['source_id'].value_counts()
# Out:
# 0    13354597
# 1     4016739
# 5     1466494
# 2      582083
# 6      151406
# Name: source_id, dtype: int64

# %%
clicks.loc[clicks['ref_hash']== '4063522808706112974'].head(4)
# Out:
#       advertiser_id  source_id                 created         country_code  \
# 130               3          0 2019-03-07 23:29:13.617  6333597102633388268
# 215               3          0 2019-03-07 23:59:09.969  6333597102633388268
# 643               3          0 2019-03-08 00:04:11.194  6333597102633388268
# 1991              3          0 2019-03-08 10:24:47.814  6333597102633388268
#
#       latitude  longitude  carrier_id                         trans_id  \
# 130   1.206055   1.070312         6.0  RcMoGv9oLfpzkpmUKwyj3GeF6RUalWE
# 215   1.206055   1.070312         6.0  _n6W8pe5-DyzcWjAyx_1Ir2MrGofV8o
# 643   1.206055   1.070312         6.0  zv6mw0gkpo22AL3deRc0VvTkeubn-0k
# 1991  1.206055   1.070312         6.0  FMEDuvfm-pllraU6dtn8vKNQGNZMgYU
#
#           os_minor  agent_device      os_major         specs_brand  brand  \
# 130   5.975656e+18           NaN  3.072849e+18  392184377613098015    NaN
# 215   5.975656e+18           NaN  3.072849e+18  392184377613098015    NaN
# ...

# %%
clicks['ref_hash'].value_counts().head(3)
# Out:
# 4063522808706112974    41
# 6841615430383729819    32
# 1244272413279716745    26
# Name: ref_hash, dtype: int64

# %%
auctions.loc[auctions['device_id'] == '4063522808706112974']
# Out:
#                       country                       date            device_id  \
# 1655      6333597102633388268 2019-03-11 14:14:52.170506  4063522808706112974
# 1665      6333597102633388268 2019-03-11 14:15:03.789245  4063522808706112974
# 2192      6333597102633388268 2019-03-11 14:14:09.838105  4063522808706112974
# 2498      6333597102633388268 2019-03-11 14:21:01.879003  4063522808706112974
# 4095      6333597102633388268 2019-03-11 13:57:53.254093  4063522808706112974
# 5703      6333597102633388268 2019-03-11 14:20:51.915593  4063522808706112974
# 6268      6333597102633388268 2019-03-11 14:15:16.714159  4063522808706112974
# 12520     6333597102633388268 2019-03-12 02:59:54.704551  4063522808706112974
# 15561     6333597102633388268 2019-03-12 03:27:57.888289  4063522808706112974
# 27730     6333597102633388268 2019-03-07 14:27:41.382050  4063522808706112974
# 28833     6333597102633388268 2019-03-07 14:04:38.386425  4063522808706112974
# ...

# %%
auctions['device_id'].value_counts().head(5)
# Out:
# 633139769114048761     27762
# 7202276635029175071    23055
# 7298861376107043945    18188
# 6302840482782120473    16400
# 5376802567578262905    16367
# Name: device_id, dtype: int64

# %%
auctions['device_id'].value_counts()
# Out:
# 633139769114048761     27762
# 7202276635029175071    23055
# 7298861376107043945    18188
# 6302840482782120473    16400
# 5376802567578262905    16367
# 8963711959081981780    14362
# 795159065504552200     12275
# 6841615430383729819    12077
# 5384039226444052914    11632
# 3198179064438296471    11565
# 519658456951133298     10541
# 2435544514359302887    10274
# 8751190726444323885    10256
# 1835469468095030098    10121
# 1800317677967270083    10036
# 9027154272484048876     9958
# 7574657722181550308     9767
# 5051610571898428259     9642
# 320899491737875154      9388
# 8292793494956750501     9315
# 201759600719985554      9158
# 8021195662481548645     9128
# 7650408579713341483     9020
# 6392567838173461255     8994
# 1478017482044456084     8839
# 6203407103275384250     8823
# 68016455690089173       8809
# 8496718680483076445     8682
# 8491787427844905567     8513
# 4834359787191717922     8495
#                        ...
# 5965915879234710356        1
# ...
